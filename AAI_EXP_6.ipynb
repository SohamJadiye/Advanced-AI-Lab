# %%
import torch
import torch.nn as nn
import numpy as np
from torchvision.datasets import CIFAR10
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

class CIFAR10Dataset(Dataset):
    def __init__(self, transform=None, train=True):
        self.transform = transform
        self.dataset = CIFAR10(root='./data', train=train, download=True, transform=self.transform)
        self.classes = self.dataset.classes

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        return image, label

train_dataset = CIFAR10Dataset(transform=transform, train=True)
valid_dataset = CIFAR10Dataset(transform=transform, train=False)

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# Model
z_size = 100
generator_layer_size = [256, 512, 1024]
discriminator_layer_size = [1024, 512, 256]
class_num = 10

class Generator(nn.Module):
    def __init__(self, generator_layer_size, z_size, class_num):
        super().__init__()
        self.z_size = z_size
        self.label_emb = nn.Embedding(class_num, class_num)
        self.model = nn.Sequential(
            nn.Linear(self.z_size + class_num, generator_layer_size[0]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[0], generator_layer_size[1]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[1], generator_layer_size[2]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[2], 3 * 32 * 32),  # CIFAR-10 images have three channels and size 32x32
            nn.Tanh()
        )

    def forward(self, z, labels):
        z = z.view(-1, self.z_size)
        c = self.label_emb(labels)
        x = torch.cat([z, c], 1)
        out = self.model(x)
        return out.view(-1, 3, 32, 32)  # Reshape to image size

class Discriminator(nn.Module):
    def __init__(self, discriminator_layer_size, class_num):
        super().__init__()
        self.label_emb = nn.Embedding(class_num, class_num)
        self.model = nn.Sequential(
            nn.Linear(3 * 32 * 32 + class_num, discriminator_layer_size[0]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[0], discriminator_layer_size[1]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[1], discriminator_layer_size[2]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[2], 1),
            nn.Sigmoid()
        )

    def forward(self, x, labels):
        x = x.view(-1, 3 * 32 * 32)
        c = self.label_emb(labels)
        x = torch.cat([x, c], 1)
        out = self.model(x)
        return out.squeeze()

# Define generator and discriminator
generator = Generator(generator_layer_size, z_size, class_num).to(device)
discriminator = Discriminator(discriminator_layer_size, class_num).to(device)

# Loss function
criterion = nn.BCELoss()

# Optimizer
g_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Training
num_epochs = 10
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        batch_size = images.size(0)
        images = images.to(device)
        labels = labels.to(device)

        # Train Discriminator
        discriminator.zero_grad()
        real_labels = torch.ones(batch_size, device=device)
        fake_labels = torch.zeros(batch_size, device=device)

        # Real images
        real_output = discriminator(images, labels)
        d_real_loss = criterion(real_output, real_labels)
        d_real_loss.backward()

        # Fake images
        z = torch.randn(batch_size, z_size, device=device)
        fake_images = generator(z, labels)
        fake_output = discriminator(fake_images.detach(), labels)
        d_fake_loss = criterion(fake_output, fake_labels)
        d_fake_loss.backward()

        d_optimizer.step()

        # Train Generator
        generator.zero_grad()
        z = torch.randn(batch_size, z_size, device=device)
        fake_images = generator(z, labels)
        outputs = discriminator(fake_images, labels)
        g_loss = criterion(outputs, real_labels)
        g_loss.backward()
        g_optimizer.step()

        if i % 100 == 0:
            print(f"Epoch [{epoch}/{num_epochs}], Step [{i}/{len(train_loader)}], "
                  f"Generator Loss: {g_loss.item():.4f}, Discriminator Loss: {d_real_loss.item() + d_fake_loss.item():.4f}")

# Generate sample images
generator.eval()
with torch.no_grad():
    z = torch.randn(10, z_size, device=device)
    labels = torch.randint(0, class_num, (10,), device=device)
    samples = generator(z, labels).cpu()

# Plot sample images
plt.figure(figsize=(10, 10))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.imshow(np.transpose(samples[i], (1, 2, 0)))
    plt.axis('off')
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch [0/10], Step [0/782], Generator Loss: 0.6948, Discriminator Loss: 1.3816
# Epoch [0/10], Step [100/782], Generator Loss: 3.1270, Discriminator Loss: 0.3562
# Epoch [0/10], Step [200/782], Generator Loss: 4.5078, Discriminator Loss: 0.3623
# Epoch [0/10], Step [300/782], Generator Loss: 3.5572, Discriminator Loss: 0.3497
# Epoch [0/10], Step [400/782], Generator Loss: 3.0959, Discriminator Loss: 0.5222
# Epoch [0/10], Step [500/782], Generator Loss: 3.3032, Discriminator Loss: 0.7132
# Epoch [0/10], Step [600/782], Generator Loss: 2.3422, Discriminator Loss: 0.6138
# Epoch [0/10], Step [700/782], Generator Loss: 2.7866, Discriminator Loss: 0.5996
# Epoch [1/10], Step [0/782], Generator Loss: 3.1479, Discriminator Loss: 0.6389
# Epoch [1/10], Step [100/782], Generator Loss: 2.6749, Discriminator Loss: 0.6920
# Epoch [1/10], Step [200/782], Generator Loss: 2.2117, Discriminator Loss: 0.8742
# Epoch [1/10], Step [300/782], Generator Loss: 2.1279, Discriminator Loss: 0.9284
# Epoch [1/10], Step [400/782], Generator Loss: 1.8837, Discriminator Loss: 0.9275
# Epoch [1/10], Step [500/782], Generator Loss: 2.4551, Discriminator Loss: 0.7951
# Epoch [1/10], Step [600/782], Generator Loss: 2.0095, Discriminator Loss: 0.7850
# Epoch [1/10], Step [700/782], Generator Loss: 2.2567, Discriminator Loss: 0.8613
# Epoch [2/10], Step [0/782], Generator Loss: 1.8402, Discriminator Loss: 0.9207
# Epoch [2/10], Step [100/782], Generator Loss: 2.3017, Discriminator Loss: 0.7484
# Epoch [2/10], Step [200/782], Generator Loss: 2.1118, Discriminator Loss: 0.9946
# Epoch [2/10], Step [300/782], Generator Loss: 2.0397, Discriminator Loss: 0.7521
# Epoch [2/10], Step [400/782], Generator Loss: 2.1243, Discriminator Loss: 0.7622
# Epoch [2/10], Step [500/782], Generator Loss: 1.7313, Discriminator Loss: 0.8248
# Epoch [2/10], Step [600/782], Generator Loss: 1.4879, Discriminator Loss: 1.0821
# Epoch [2/10], Step [700/782], Generator Loss: 2.0524, Discriminator Loss: 0.7325
# Epoch [3/10], Step [0/782], Generator Loss: 1.7228, Discriminator Loss: 0.8647
# Epoch [3/10], Step [100/782], Generator Loss: 2.1041, Discriminator Loss: 0.7969
# Epoch [3/10], Step [200/782], Generator Loss: 1.3976, Discriminator Loss: 0.9915
# Epoch [3/10], Step [300/782], Generator Loss: 2.2187, Discriminator Loss: 0.7363
# Epoch [3/10], Step [400/782], Generator Loss: 2.0580, Discriminator Loss: 0.9372
# Epoch [3/10], Step [500/782], Generator Loss: 1.8209, Discriminator Loss: 0.7989
# Epoch [3/10], Step [600/782], Generator Loss: 1.8052, Discriminator Loss: 0.9290
# Epoch [3/10], Step [700/782], Generator Loss: 1.4207, Discriminator Loss: 0.9915
# Epoch [4/10], Step [0/782], Generator Loss: 2.0385, Discriminator Loss: 0.9141
# Epoch [4/10], Step [100/782], Generator Loss: 1.6573, Discriminator Loss: 0.8232
# Epoch [4/10], Step [200/782], Generator Loss: 1.5754, Discriminator Loss: 0.8778
# Epoch [4/10], Step [300/782], Generator Loss: 1.7922, Discriminator Loss: 0.9969
# Epoch [4/10], Step [400/782], Generator Loss: 1.2109, Discriminator Loss: 1.0475
# Epoch [4/10], Step [500/782], Generator Loss: 1.4679, Discriminator Loss: 1.0966
# Epoch [4/10], Step [600/782], Generator Loss: 1.6385, Discriminator Loss: 0.9748
# Epoch [4/10], Step [700/782], Generator Loss: 1.5209, Discriminator Loss: 0.9868
# Epoch [5/10], Step [0/782], Generator Loss: 1.5215, Discriminator Loss: 1.1574
# Epoch [5/10], Step [100/782], Generator Loss: 1.4320, Discriminator Loss: 1.0959
# Epoch [5/10], Step [200/782], Generator Loss: 1.2284, Discriminator Loss: 1.0467
# Epoch [5/10], Step [300/782], Generator Loss: 1.3158, Discriminator Loss: 0.9681
# Epoch [5/10], Step [400/782], Generator Loss: 1.4449, Discriminator Loss: 1.0695
# Epoch [5/10], Step [500/782], Generator Loss: 1.4997, Discriminator Loss: 0.9452
# Epoch [5/10], Step [600/782], Generator Loss: 1.2517, Discriminator Loss: 1.1340
# Epoch [5/10], Step [700/782], Generator Loss: 1.3363, Discriminator Loss: 0.9355
# Epoch [6/10], Step [0/782], Generator Loss: 1.6405, Discriminator Loss: 1.1385
# Epoch [6/10], Step [100/782], Generator Loss: 1.1806, Discriminator Loss: 1.0205
# Epoch [6/10], Step [200/782], Generator Loss: 1.3213, Discriminator Loss: 1.2152
# Epoch [6/10], Step [300/782], Generator Loss: 1.2453, Discriminator Loss: 1.1590
# Epoch [6/10], Step [400/782], Generator Loss: 1.3214, Discriminator Loss: 1.1980
# Epoch [6/10], Step [500/782], Generator Loss: 1.0312, Discriminator Loss: 1.0638
# Epoch [6/10], Step [600/782], Generator Loss: 1.2986, Discriminator Loss: 1.2635
# Epoch [6/10], Step [700/782], Generator Loss: 1.2137, Discriminator Loss: 1.2474
# Epoch [7/10], Step [0/782], Generator Loss: 1.3271, Discriminator Loss: 1.1322
# Epoch [7/10], Step [100/782], Generator Loss: 1.1346, Discriminator Loss: 1.2064
# Epoch [7/10], Step [200/782], Generator Loss: 1.1381, Discriminator Loss: 1.1848
# Epoch [7/10], Step [300/782], Generator Loss: 1.1371, Discriminator Loss: 1.0137
# Epoch [7/10], Step [400/782], Generator Loss: 1.0190, Discriminator Loss: 1.2721
# Epoch [7/10], Step [500/782], Generator Loss: 1.1058, Discriminator Loss: 1.2006
# Epoch [7/10], Step [600/782], Generator Loss: 0.9600, Discriminator Loss: 1.2190
# Epoch [7/10], Step [700/782], Generator Loss: 1.2177, Discriminator Loss: 1.2194
# Epoch [8/10], Step [0/782], Generator Loss: 1.0748, Discriminator Loss: 1.3075
# Epoch [8/10], Step [100/782], Generator Loss: 1.1234, Discriminator Loss: 1.1565
# Epoch [8/10], Step [200/782], Generator Loss: 1.2202, Discriminator Loss: 1.2020
# Epoch [8/10], Step [300/782], Generator Loss: 0.9915, Discriminator Loss: 1.0630
# Epoch [8/10], Step [400/782], Generator Loss: 1.0307, Discriminator Loss: 1.1577
# Epoch [8/10], Step [500/782], Generator Loss: 1.0436, Discriminator Loss: 1.1142
# Epoch [8/10], Step [600/782], Generator Loss: 0.9351, Discriminator Loss: 1.2840
# Epoch [8/10], Step [700/782], Generator Loss: 1.0300, Discriminator Loss: 1.1290
# Epoch [9/10], Step [0/782], Generator Loss: 1.1700, Discriminator Loss: 1.0999
# Epoch [9/10], Step [100/782], Generator Loss: 1.1349, Discriminator Loss: 1.0814
# Epoch [9/10], Step [200/782], Generator Loss: 1.1528, Discriminator Loss: 1.1925
# Epoch [9/10], Step [300/782], Generator Loss: 0.9837, Discriminator Loss: 1.1931
# Epoch [9/10], Step [400/782], Generator Loss: 1.0749, Discriminator Loss: 1.2675
# Epoch [9/10], Step [500/782], Generator Loss: 1.1114, Discriminator Loss: 1.2660
# Epoch [9/10], Step [600/782], Generator Loss: 0.9521, Discriminator Loss: 1.3898
# Epoch [9/10], Step [700/782], Generator Loss: 1.0352, Discriminator Loss: 1.2063
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
